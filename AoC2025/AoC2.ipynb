# %% [markdown]
# # PART 1

# %%
text= "5-10"
list_one=text.split("-")
start=int(list_one[0])
end=int(list_one[1])
print(start,end)
# Out:
# 5 10

# %%
def range_checker(r):
    list_one=r.split("-")
    start=int(list_one[0])
    end=int(list_one[1])+ 1

    invalid_can=[]
    for s in range(start,end):
        if is_invalid(s)== True:
            invalid_can.append(int(s))
    return sum(invalid_can)

# %%
range_checker("38593856-38593862")
#OUT SHOULD BE: 38593859
# Out:
# 38593859

# %%
def is_invalid(n):
    s=str(n) #THIS LINE TOOK ME 2 HOURS
    halfs=len(s)//2
    second_half=s[:halfs]
    first_half=s[halfs:]
    if first_half ==second_half:
        return True
    else:
        return False

# %%
is_invalid("123123")
# Out:
# False

# %%
input="9100-11052,895949-1034027,4408053-4520964,530773-628469,4677-6133,2204535-2244247,55-75,77-96,6855-8537,55102372-55256189,282-399,228723-269241,5874512-6044824,288158-371813,719-924,1-13,496-645,8989806846-8989985017,39376-48796,1581-1964,699387-735189,85832568-85919290,6758902779-6759025318,198-254,1357490-1400527,93895907-94024162,21-34,81399-109054,110780-153182,1452135-1601808,422024-470134,374195-402045,58702-79922,1002-1437,742477-817193,879818128-879948512,407-480,168586-222531,116-152,35-54"
working_data= input.split(',')
total=0
for r in working_data:
    total+=range_checker(r)
print(total)
#total should be:1227775554
# Out:
# 18952700150

# %% [markdown]
# # PART 2

# %%
#halves will no longer work
def is_invalid2(n):
    s=str(n)
    halfs=len(s)//2
    repeats=s[:i]
