# %%
total = 0
for char in "tinfoil":
    total = total + 1
    print(total)
print(total)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 7

# %%
original = "tin"
result = ""
for char in original:
    result = char + result
    print(result)
print(result)
#Rewrite the complement via this.
# Out:
# t
# it
# nit
# nit

# %%
words = ["red", "green", "blue"]
result = ""
for word in words:
    result = result + word
print(result)
# Out:
# redgreenblue

# %%
acronym = ""
for word in ["red", "green", "blue"]:
    acronym = acronym + word[0].upper()
print(acronym)
# Out:
# RGB

# %%
#CONDITIONALS
X==8
x!=8

# %%
numbers = [2, 6, -7, 5,0]
for number in numbers:
    if number > 0:
        print("greater than zero")
    elif number <0:
        print("negative number")
    else:
        print("number is zero")
# Out:
# greater than zero
# greater than zero
# negative number
# greater than zero
# number is zero

# %%
fruits= ["apple", "strawberry", "banana", "grape", "pineapple","banana", "kiwi", "pomelo"]
#there are len(fruits)
for i in range(len(fruits)):
    fruit = fruits[i]
    print("the fruit here is a", fruits[i])
    if fruits[i] == "banana":
        print("found a banana at spot", i)
    


#for fruit in fruits:
    #if fruit == "banana":
     #   print(fruit[])
    #else:
       # print("there is no bananas")
# Out:
# the fruit here is a apple
# the fruit here is a strawberry
# the fruit here is a banana
# found a banana at spot 2
# the fruit here is a grape
# the fruit here is a pineapple
# the fruit here is a banana
# found a banana at spot 5
# the fruit here is a kiwi
# the fruit here is a pomelo
